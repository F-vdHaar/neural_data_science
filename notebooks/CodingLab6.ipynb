# %% [markdown]
# _Neural Data Science_
#
# Lecturer: Dr. Jan Lause, Prof. Dr. Philipp Berens
#
# Tutors: Jonas Beck, Fabio Seel, Julius Würzler
#
# Summer term 2025
#
# Student names: <span style='background: yellow'>*FILL IN YOUR NAMES HERE* </span>
#
# LLM Disclaimer: <span style='background: yellow'>*Did you use an LLM to solve this exercise? If yes, which one and where did you use it? [Copilot, Claude, ChatGPT, etc.]* </span>

# %% [markdown]
# # Coding Lab 6
#
# In this exercise we are going to fit a latent variable model (Poisson GPFA) to both toy data and real data from monkey primary visual cortex. For details, see [Ecker et al. 2014](https://www.cell.com/neuron/pdf/S0896-6273(14)00104-4.pdf).

# %% [markdown]
# ## Preliminaries
#
# ### 1. Code
#
# The toolbox we are going to use contains an implementation of the EM algorithm to fit the poisson-gpfa.
#
# Assuming you `git clone https://github.com/berenslab/poisson-gpfa` to the parent directory and have the following directory structure:
#
#
# ```
# ├── data/
# │   └── nds_cl_6_data.mat
# ├── poisson-gpfa/
# ├── notebooks
# │   └── CodingLab6.ipynb
# ├── matplotlib_style.txt
# ├── requirements.txt
# ```
#
# then you can import the related functions via:
#
# ```
# import sys
# sys.path.append('../poisson-gpfa/')
# sys.path.append('../poisson-gpfa/funs')
#
# import funs.util as util
# import funs.engine as engine
# ```
#
# Change the paths if you have a different directory structure. For the details of the algorithm, please refer to the thesis `hooram_thesis.pdf` from ILIAS.
#
# ### 2. Data
#
# Download the data file ```nds_cl_6_data.mat``` from ILIAS and save it in a ```data/``` folder.

# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt

# style
import seaborn as sns

# poisson-gpfa
import sys
sys.path.append('../poisson-gpfa/')
sys.path.append('../poisson-gpfa/funs')

import funs.util as util
import funs.engine as engine

# %matplotlib inline

# %load_ext jupyter_black

# %load_ext watermark
# %watermark --time --date --timezone --updated --python --iversions --watermark -p sklearn
# Out:
# Last updated: 2026-05-30 19:48:21W. Europe Daylight Time
#
# Python implementation: CPython
# Python version       : 3.12.13
# IPython version      : 9.14.0
#
# sklearn: 1.7.0
#
# sys       : 3.12.13 | packaged by Anaconda, Inc. | (main, Mar 19 2026, 20:16:45) [MSC v.1942 64 bit (AMD64)]
# seaborn   : 0.13.2
# scipy     : 1.13.0
# matplotlib: 3.10.3
# numpy     : 2.2.6
#
# Watermark: 2.5.0

# %%
plt.style.use("../matplotlib_style.txt")

# %% [markdown]
# ## Task 1. Generate some toy data to test the poisson-GPFA code
#
# We start by verifying our code on toy data. The cell below contains code to generate data for 30 neurons, 100 trials (1000 ms each) and 50ms bin size. The neurons' firing rate $\lambda_k$ is assumed to be a constant $d_k$ modulated by a one-dimensional latent state $x$, which is drawn from a Gaussian process:
#
# $\lambda_k = \exp(c_kx + d_k)$
#
# Each neuron's weight $c_k$ is drawn randomly from a normal distribution and spike counts are sampled form a Poisson distribution with rate $\lambda_k$.
#
# Your task is to fit a Poisson GPFA model with one latent variable to this data (see `engine.PPGPFAfit`).
#
# Hint: You can use `util.dataset?`, `engine.PPGPFAfit?` or `util.initializeParams?` to find out more about the provided package.
#
# *Grading: 3 pts*

# %%
# ---------------------------------
# simulate a training set (0.5 pts)
# ---------------------------------

# Initialize random number generator
rng = np.random.default_rng(40)

# Specify dataset & fitting parameters

params = {"C": rng.random((30, 1)), "d": rng.random((30,)), "tau": rng.random((1))}


# Sample from the model (make a toy dataset)
training_set = util.dataset(
    xdim=1,
    ydim=30,
    trialDur=1000,
    binSize=50,
    numTrials=100,
    params=params,
    seed=40,
)
# Out:
# +------------- Simulated Dataset Options -------------+
#                                                     1 | Dimensionality of Latent State
#                                                    30 | Dimensionality of Observed State (# neurons)
#                                                  1000 | Duration of trials (ms):
#                                                    50 | Size of bins (ms):
#                                                   100 | Number of Trials
# +-----------------------------------------------------+
# Sampling trial 100 ...
# Average firing rate per neuron in this dataset: 37.185 Hz.

# %% [markdown]
# ### Fit the model

# %%
# -----------------------
# fit the model (0.5 pts)
# -----------------------

# Initialize parameters using Poisson-PCA
fit_params = util.initializeParams(xdim=1, ydim=30, experiment=training_set)

# choose sensible parameters and run fit
fitToy = engine.PPGPFAfit(experiment=training_set, initParams=fit_params, verbose=True)
# Out:
# Initializing parameters with Poisson-PCA..
# +-------------------- Fit Options --------------------+
#                                                     1 | Dimensionality of Latent State
#                                                    30 | Dimensionality of Observed State (# neurons)
#                                                Online | EM mode:
#                                                    50 | Max EM iterations:
#                                               laplace | Inference Method
#                                                `diag` | Online Param Update Method
#                                                     5 | Batch size (trials):
# +-----------------------------------------------------+
# laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:   1 of  50, nPLL: = 312.2218laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:   2 of  50, nPLL: = -534.1589laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:   3 of  50, nPLL: = 616.5972laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:   4 of  50, nPLL: = -365.1905laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:   5 of  50, nPLL: = -492.3276laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:   6 of  50, nPLL: = -468.8312laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:   7 of  50, nPLL: = -244.4601laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:   8 of  50, nPLL: = -313.5701laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:   9 of  50, nPLL: = 141.0695laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  10 of  50, nPLL: = 28.0625laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  11 of  50, nPLL: = -472.1129laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  12 of  50, nPLL: = -423.2999laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  13 of  50, nPLL: = -304.3413laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  14 of  50, nPLL: = -120.5664laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  15 of  50, nPLL: = -114.7494laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  16 of  50, nPLL: = -78.6449laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  17 of  50, nPLL: = 431.6822laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  18 of  50, nPLL: = 74.6780laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  19 of  50, nPLL: = 849.6179laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  20 of  50, nPLL: = 194.1162laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  21 of  50, nPLL: = -197.4108laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  22 of  50, nPLL: = -228.3032laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  23 of  50, nPLL: = -342.2053laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  24 of  50, nPLL: = 204.5767laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  25 of  50, nPLL: = -421.9096laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  26 of  50, nPLL: = -120.2721laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  27 of  50, nPLL: = -36.6520laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  28 of  50, nPLL: = -378.4734laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  29 of  50, nPLL: = -87.0748laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  30 of  50, nPLL: = -467.7966laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  31 of  50, nPLL: = -178.9845laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  32 of  50, nPLL: = -66.7897laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  33 of  50, nPLL: = 143.9647laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  34 of  50, nPLL: = -415.7597laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  35 of  50, nPLL: = -481.5221laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  36 of  50, nPLL: = -408.6401laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  37 of  50, nPLL: = 51.3184laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  38 of  50, nPLL: = -60.4715laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  39 of  50, nPLL: = -170.9296laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  40 of  50, nPLL: = -511.7225laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  41 of  50, nPLL: = -127.7526laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  42 of  50, nPLL: = -345.5899laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  43 of  50, nPLL: = -509.6337laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  44 of  50, nPLL: = -108.0166laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  45 of  50, nPLL: = -371.8889laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  46 of  50, nPLL: = -260.9768laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  47 of  50, nPLL: = -297.8699laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  48 of  50, nPLL: = -293.1356laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  49 of  50, nPLL: = -340.8486laplace inference trajectory of trial 1...
# laplace inference trajectory of trial 2...
# laplace inference trajectory of trial 3...
# laplace inference trajectory of trial 4...
# laplace inference trajectory of trial 5...
# Learning C,d...
# Cd optimization successful.
# Learning GP timescale constants
# Iteration:  50 of  50, nPLL: = 751.4791
# This dataset is a simulated dataset.
# Processing performance against ground truth parameters...

# %%
# some useful functions
def allTrialsState(fit: engine.PPGPFAfit, p) -> np.ndarray:
    """Reshape the latent signal and the spike counts"""
    x = np.zeros([p, 0])
    for i in range(len(fit.infRes["post_mean"])):
        x = np.concatenate((x, fit.infRes["post_mean"][i]), axis=1)
    return x


def allTrialsX(training_set: util.dataset) -> np.ndarray:
    """Reshape the ground truth
    latent signal and the spike counts"""
    x_gt = np.array([])
    for i in range(len(training_set.data)):
        x_gt = np.concatenate((x_gt, training_set.data[i]["X"][0]), axis=0)
    return x_gt

# %% [markdown]
# ### Plot the ground truth vs. inferred model
# Verify your fit by plotting both ground truth and inferred parameters for:
# 1. weights C
# 2. biases d
# 3. latent state x
#
# Note that the sign of fitted latent state and its weights are ambiguous (you can flip both without changing the model). Make sure you correct the sign for the plot if it does not match the ground truth.

# %%
# All trials latent state vector
x_est = allTrialsState(fitToy, 1)
x_true = allTrialsX(training_set)

# %%
# ------------------------------------------------------
# Plot ground truth vs. inferred model
# Plot the weights `C`, biases `d` and latent states (2 pts)
# ------------------------------------------------------

fit_C = fitToy.optimParams["C"] * -1


# add plot
fig, ax = plt.subplot_mosaic([["C", "d"], ["latent", "latent"]])

# For d & C consider also plotting the optimal weights as a dotted line for reference
ax["C"].plot(range(30), fit_C.flatten())
ax["C"].plot(params["C"].flatten(), "--")
ax["C"].set_title("latent weights C")
ax["C"].set_xlabel("Neuron")


ax["d"].plot(range(30), fitToy.optimParams["d"].flatten())
ax["d"].plot(params["d"].flatten(), "--")
ax["d"].set_title("latent weights C")
ax["d"].set_xlabel("Neuron")

# For the latent states consider seperating each trial by a vertical line
# plot only for a subset of trials
ax["latent"].plot(x_est.flatten()[:20])
ax["latent"].plot(x_true.flatten()[:20])
ax["latent"].set_xticks([i for i in range(1, 21, 3)])
ax["latent"].set_title("Latent trajectory")
ax["latent"].set_xlabel("Trials")


fig.suptitle("Ground truth vs Inferred model")
# Out:
# Text(0.5, 0.98, 'Ground truth vs Inferred model')

# %% [markdown]
# ## Task 2: Fit GPFA model to real data.
#
# We now fit the model to real data and cross-validate over the dimensionality of the latent variable.
#
# *Grading: 4 pts*

# %% [markdown]
# ### Load data
#
# The cell below implements loading the data and encapsulates it into a class that matches the interface of the Poisson GPFA engine. You don't need to do anything here.

# %%
class EckerDataset:
    """Loosy class"""

    def __init__(
        self,
        path: str,
        subject_id: int = 0,
        ydim: int = 55,
        trialDur: int = 2000,
        binSize: int = 100,
        numTrials: int = 100,
        ydimData: bool = False,
        numTrData: bool = True,
    ):
        # T = binSize #int(trialDur/binSize)
        T = int(trialDur / binSize)
        matdat = sio.loadmat(path)
        self.matdat = matdat
        data = []
        trial_durs = []
        for trial_id in range(numTrials):
            trial_time = matdat["spikeTimes"][:, trial_id][0]
            trial_big_time = np.min(trial_time)
            trial_end_time = np.max(trial_time)
            trial_durs.append(trial_end_time - trial_big_time)
        for trial_id in range(numTrials):
            Y = []
            spike_time = []
            data.append(
                {
                    "Y": matdat["spikeCounts"][:, :, trial_id],
                    "spike_time": matdat["spikeTimes"][:, trial_id],
                }
            )
        self.T = T
        self.trial_durs = trial_durs
        self.data = data
        self.trialDur = trialDur
        self.binSize = binSize
        self.numTrials = numTrials
        self.ydim = ydim
        util.dataset.getMeanAndVariance(self)
        util.dataset.getAvgFiringRate(self)
        util.dataset.getAllRaster(self)

# %%
path = "../data/nds_cl_6_data.mat"
data = EckerDataset(path)

# %% [markdown]
# ### Fit Poisson GPFA models and perform model comparison
#
# Split the data into 80 trials used for training and 20 trials held out for performing model comparison. On the training set, fit models using one to five latent variables. Compute the performance of each model on the held-out test set.
#
# Hint: You can use the `crossValidation` function in the Poisson GPFA package.
#
# Optional: The `crossValidation` function computes the sum of the squared errors (SSE) on the test set, which is not ideal. The predictive log-likelihood under the Poisson model would be a better measure, which you are welcome to compute instead.

# %% [markdown]
# ### Derivation for log-likelihood
#
# _You can add your calculations in_ $\LaTeX$ _here_.
#
# $p_\lambda(x_t) = \ldots$
#
# $L(\lambda_k; x_1, ..., x_N) = \ldots$
#
# $log(L) = l(\lambda_k; x_1, ..., x_N) = \ldots$

# %%
# ------------------------------
# Perfom cross validation (1 pt)
# ------------------------------


# do the actual cross validation
xval = util.crossValidation(
    experiment=data, numTrainingTrials=80, numTestTrials=20, maxXdim=5, maxEMiter=10
)
# Out:
# Assessing optimal latent dimensionality will take a long time.
# Initializing parameters with Poisson-PCA..
# +-------------------- Fit Options --------------------+
#                                                     1 | Dimensionality of Latent State
#                                                    55 | Dimensionality of Observed State (# neurons)
#                                                 Batch | EM mode:
#                                                    10 | Max EM iterations:
#                                               laplace | Inference Method
# +-----------------------------------------------------+
# Iteration:  10 of  10, nPLL: = -399.6673Performing leave-one-out cross validation...
# Initializing parameters with Poisson-PCA..
# +-------------------- Fit Options --------------------+
#                                                     2 | Dimensionality of Latent State
#                                                    55 | Dimensionality of Observed State (# neurons)
#                                                 Batch | EM mode:
#                                                    10 | Max EM iterations:
#                                               laplace | Inference Method
# +-----------------------------------------------------+
# Iteration:  10 of  10, nPLL: = -360.2901Performing leave-one-out cross validation...
# Initializing parameters with Poisson-PCA..
# +-------------------- Fit Options --------------------+
#                                                     3 | Dimensionality of Latent State
#                                                    55 | Dimensionality of Observed State (# neurons)
#                                                 Batch | EM mode:
#                                                    10 | Max EM iterations:
#                                               laplace | Inference Method
# +-----------------------------------------------------+
# Iteration:  10 of  10, nPLL: = -355.3933Performing leave-one-out cross validation...
# Initializing parameters with Poisson-PCA..
# +-------------------- Fit Options --------------------+
#                                                     4 | Dimensionality of Latent State
#                                                    55 | Dimensionality of Observed State (# neurons)
#                                                 Batch | EM mode:
#                                                    10 | Max EM iterations:
#                                               laplace | Inference Method
# +-----------------------------------------------------+
# Iteration:  10 of  10, nPLL: = -348.6780Performing leave-one-out cross validation...
# Initializing parameters with Poisson-PCA..
# +-------------------- Fit Options --------------------+
#                                                     5 | Dimensionality of Latent State
#                                                    55 | Dimensionality of Observed State (# neurons)
#                                                 Batch | EM mode:
#                                                    10 | Max EM iterations:
#                                               laplace | Inference Method
# +-----------------------------------------------------+
# Iteration:  10 of  10, nPLL: = -333.3507Performing leave-one-out cross validation...

# %% [markdown]
# ### Plot the test error
#
# Make a plot of the test error for the five different models. As a baseline, please also include the test error of a model without a latent variable. This is essentially the SSE of a constant rate model (or Poisson likelihood if you did the optional part above). Note: We assume a constant firing rate across trials, but not necessarily across time.

# %%
# --------------------------------------------------------------------------------
# Compute and plot the test errors for the different latent variable models (1 pt)
# --------------------------------------------------------------------------------

train_set, test_set = util.splitTrainingTestDataset(
    data, numTrainingTrials=80, numTestTrials=20
)

test_trials = np.array([test_set.data[i]["Y"] for i in range(test_set.numTrials)])
baseline_model = np.tile(np.mean(test_trials, axis=0), (test_set.numTrials, 1, 1))

# compute baseline error
baseline_error = np.sum((test_trials - baseline_model) ** 2)

# %%
# -------------------------------------------------------------------------
# Compute and plot the test errors for the different latent variable models
# and answer the questions below (1+1 pts)
# -------------------------------------------------------------------------

# Your plot here
fig, ax = plt.subplots(figsize=(4, 3))

# plot model error
ax.plot(xval.errs)

# plot baseline
ax.axhline(baseline_error, linestyle="--")
ax.set_title("Model error vs baseline")
ax.set_xlabel("Latent variables")
ax.set_ylabel("Error")

plt.show()

# %% [markdown]
# ### Questions
#
# Is the baseline error (0 latents) about what you expect in relation to the other models? Why or why not?
# No, I expect the baseline error to be higher than the other models, since it predicts the average spike counts over trials
#
# Can you identify a "best model". If so, which is it and what does this say about the structure of the latent state?
#
# _YOUR ANSWER GOES HERE_

# %% [markdown]
# ## Task 3. Visualization: population rasters and latent state.
# Use the model with a single latent state.
#
# Create a raster plot where you show for each trial the spikes of all neurons as well as the trajectory of the latent state `x` (take care of the correct time axis). Sort the neurons by their weights `c_k`. Plot only the first 20 trials.
#
# *Grading: 2 pts*

# %%
from numpy import matlib

# Your plot here
fig, axs = plt.subplots(10, 2, figsize=(14, 14))

ts = np.linspace(0, 2000, 100)
xa = 0.15  # scaling constant
xs = 0.7 * xa * np.sin(ts / 1000 * 3.4 * 2 * np.pi) + xa  # creates a sine wave

fit_model = xval.fits[0]
latent_model = fit_model.infRes["post_mean"]
C = fit_model.optimParams["C"]
sorted_idx = np.argsort(C[:, 0])

with sns.axes_style("ticks"):
    for ntrial, ax in enumerate(axs.flat):
        x = np.arange(50, 2000, 100)  # assume binsize of 100ms

        # --------------------------------------------------------
        # plot the raster for each neuron and latent state (2 pts)
        # --------------------------------------------------------

        trial_spikes = data.data[ntrial]["spike_time"]
        row = 0

        for i in sorted_idx:
            row += 2
            ax.vlines(trial_spikes[i], row + 0.5, row + 1.5)

        latent = latent_model[ntrial].transpose()
        latent = (latent - latent.min()) / (latent.max() - latent.min())

        ax.plot(x, latent * 20, "r")
        ax.text(
            -0.05, 0.5, str(ntrial + 1), transform=ax.transAxes, ha="right", va="center"
        )
        # hint: can be plotted on top of the corresponding raster

        # sort neurons by weight

        if ntrial == 0:
            ax.legend()
        if ntrial == 1:
            ax.plot([1000, 2000], [-30, -30], color="green")
            ax.text(1300, -50, "1sec")
        if ntrial < 2:
            ax.plot(ts, (xs * 40) + data.ydim, "k", color="black")

        ax.set_yticks([])
        ax.set_xticks([])

    for ax in axs[-1]:
        ax.set_xticks([0, 1000, 2000])
        ax.set_xlabel("Time (ms)")

    fig.suptitle("Spike Raster plot with latent trajectories")
    fig.supylabel("Trial")
# Out:
# C:\Users\janaurmi\AppData\Local\Temp\ipykernel_27912\2227703830.py:42: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# C:\Users\janaurmi\AppData\Local\Temp\ipykernel_27912\2227703830.py:47: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k" (-> color=(0.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   ax.plot(ts, (xs * 40) + data.ydim, "k", color="black")

# %% [markdown]
# ## Task 4. Visualization of covariance matrix.
#
# Plot (a) the covariance matrix of the observed data as well as its approximation using (b) one and (c) five latent variable(s). Use the analytical solution for the covariance matrix of the approximation*. Note that the solution is essentially the mean and covariance of the [log-normal distribution](https://en.wikipedia.org/wiki/Log-normal_distribution).
#
# $ \mu = \exp(\frac{1}{2} \text{ diag}(CC^T)+d)$
#
# $ \text{Cov}= \mu\otimes\mu^T \odot \exp(CC^T)+\mu\cdot \mathbb{I} - \mu\otimes\mu^T$
#
# *[Krumin, M., and Shoham, S. (2009). Generation of Spike Trains with Controlled Auto- and Cross-Correlation Functions. Neural Computation 21, 1642–1664](http://www.mitpressjournals.org/doi/10.1162/neco.2009.08-08-847).
#
# *Grading: 3 pts*

# %%
# --------------------------------------------------------------
# Complete the analytical solution for the covariance matrix of
# the approximation using the provide equations (2 pts)
# --------------------------------------------------------------


def cov(fit: engine.PPGPFAfit) -> np.ndarray:

    weights = fit.optimParams["C"]
    d = fit.optimParams["d"]
    mu = np.exp(0.5 * (np.diag(weights @ weights.T)) + d)

    c = (np.outer(mu, mu) * np.exp(weights @ weights.T) + np.diag(mu)) - np.outer(
        mu, mu
    )

    return c, mu


# --------------------------------------------------------------
# Plot the covariance matrix of
# (1) the observed data
# (2) its approximation using 1 latent variable
# (3) its approximation using 5 latent variable
# and explain how they compare (1+1 pts).
# --------------------------------------------------------------

obs_corr = np.cov(data.all_raster)
opt_r1, mu1 = cov(xval.fits[0])
opt_r5, mu5 = cov(xval.fits[4])

# HINT: Think about which type of colormap and ranges are appropriate here.

fig, axs = plt.subplots(1, 3, figsize=(10, 3.5))
# add plot to visualize the differences in the covariance matrices

vmin = min(opt_r1.min(), opt_r5.min(), obs_corr.min())
vmax = max(opt_r1.max(), opt_r5.max(), obs_corr.max())

corr = axs[0].imshow(obs_corr, vmin=vmin, vmax=vmax)
axs[0].set_title("Observed data")

corr_1 = axs[1].imshow(opt_r1)
axs[1].set_title("one latent variable")

corr_5 = axs[2].imshow(opt_r5)
axs[2].set_title("Five latent variables")

fig.colorbar(corr_5, ax=axs)
fig.suptitle("Covariance Matrices")
plt.show()

# %% [markdown]
# ### Questions
#
# What do you see / expect to see?
#
# _YOUR ANSWER GOES HERE_
